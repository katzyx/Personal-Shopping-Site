# %%
import os
import sys
import glob
import chromadb # type: ignore
import json
from typing import List, Dict
from llama_index.core import Document, VectorStoreIndex, StorageContext # type: ignore
from llama_index.core.readers.json import JSONReader # type: ignore
from llama_index.llms.openai import OpenAI # type: ignore
from llama_index.vector_stores.chroma import ChromaVectorStore # type: ignore
from llama_index.embeddings.huggingface import HuggingFaceEmbedding # type: ignore
from llama_index.core import Settings # type: ignore
from llama_index.core.extractors import BaseExtractor #type: ignore
from llama_index.core.schema import BaseNode, MetadataMode #type: ignore
from llama_index.core.vector_stores import MetadataFilter, MetadataFilters #type: ignore
from llama_index.core.indices.struct_store import JSONQueryEngine #type: ignore
from IPython.display import Markdown, display
import openai

# %%
json_schema = {
    "$schema": "http://json-schema.org/draft-07/schema#",
    "title": "ProductList",
    "type": "object",
    "description": "A list of cosmetic products with detailed information.",
    "properties": {
        "products": {
            "type": "array",
            "description": "An array of product objects, each containing information about a specific cosmetic product.",
            "items": {
                "type": "object",
                "properties": {
                    "product_id": {
                        "type": "string",
                        "description": "A unique identifier for the product."
                    },
                    "name": {
                        "type": "string",
                        "description": "The full name of the product."
                    },
                    "brand": {
                        "type": "string",
                        "description": "The brand that manufactures the product."
                    },
                    "categories": {
                        "type": "string",
                        "description": "A comma-separated string of categories that the product belongs to (e.g., Hair, Hair Styling & Treatments)."
                    },
                    "price": {
                        "type": "number",
                        "description": "The price of the product in the Canadian dollars (CAD)."
                    },
                    "about": {
                        "type": "string",
                        "description": "A detailed description of the product, including its benefits, who it is suitable for, and key ingredients."
                    },
                    "ingredients": {
                        "type": "string",
                        "description": "A list of ingredients contained in the product."
                    },
                    "how_to_use": {
                        "type": "string",
                        "description": "Instructions on how to properly use the product."
                    },
                    "num_reviews": {
                        "type": "integer",
                        "description": "The total number of reviews submitted for this product."
                    },
                    "overall_rating": {
                        "type": "number",
                        "description": "The average rating of the product based on customer reviews, typically on a scale of 1 to 5."
                    },
                    "product_url": {
                        "type": "string",
                        "format": "uri",
                        "description": "The URL link to the product's page on the retailer's website."
                    },
                    "image_url": {
                        "type": "string",
                        "format": "uri",
                        "description": "The URL of the main image representing the product."
                    },
                    "shades": {
                        "type": "array",
                        "description": "An array of available shades or sizes for the product, each with specific details.",
                        "items": {
                            "type": "object",
                            "properties": {
                                "shade_name": {
                                    "type": "string",
                                    "description": "The name of the shade or size option (e.g., 2 oz / 60 ml)."
                                },
                                "shade_descriptor": {
                                    "type": "string",
                                    "description": "A description of the shade or size, such as the supply duration (e.g., 4 Month Supply)."
                                },
                                "shade_image_url": {
                                    "type": "string",
                                    "format": "uri",
                                    "description": "The URL of the image representing this specific shade or size."
                                }
                            },
                            "required": ["shade_name", "shade_descriptor", "shade_image_url"]
                        }
                    },
                    "reviews": {
                        "type": "array",
                        "description": "An array of customer reviews for the product, detailing user experiences and ratings.",
                        "items": {
                            "type": "object",
                            "properties": {
                                "review_title": {
                                    "type": "string",
                                    "description": "The title of the review summarizing the user's opinion."
                                },
                                "review_rating": {
                                    "type": "integer",
                                    "minimum": 1,
                                    "maximum": 5,
                                    "description": "The rating given by the reviewer, on a scale from 1 to 5."
                                },
                                "review_shade_purchased": {
                                    "type": "string",
                                    "description": "The specific shade or size of the product that the reviewer purchased, if applicable."
                                },
                                "review_buyer_description": {
                                    "type": "string",
                                    "description": "A brief description of the reviewer, including features like eye color, hair color, skin tone, and skin type."
                                },
                                "review_text": {
                                    "type": "string",
                                    "description": "The full text of the review, describing the user's experience with the product."
                                }
                            },
                            "required": [
                            "review_title",
                            "review_rating",
                            "review_buyer_description",
                            "review_text"
                            ]
                        }
                    }
                },
                "required": [
                    "product_id",
                    "name",
                    "brand",
                    "categories",
                    "price",
                    "about",
                    "ingredients",
                    "how_to_use",
                    "num_reviews",
                    "overall_rating",
                    "product_url",
                    "image_url",
                ]
                }
        }
        },
    "required": ["products"]
}

# %%
directory_path = '/Users/floriafang/Documents/UofT/capstone/Personal-Shopping-Site/web_scraping/products_json'

json_value = '{\n\t"products": ['

json_files = glob.glob(os.path.join(directory_path, "*.json"))
for count, json_file in enumerate(json_files):
    with open(json_file, 'r') as json_data:
        data = json_data.readlines()
    json_value += '\n'
    
    for line in data:
        json_value += '\t' + line
    if count != len(json_files) - 1:
        json_value += ','

json_value += '\n\t]\n}'

print(json_value[:10000])

json_value = json.loads(json_value)
# Out:
# {
# 	"products": [
# 	{
# 	    "product_id": "244",
# 	    "name": "Horizon Lip Pencil",
# 	    "brand": "Cheekbone Beauty",
# 	    "categories": "Makeup, Lip, Lip Liner",
# 	    "price": 22.0,
# 	    "about": "What it is:...What Else You Need to Know:..",
# 	    "ingredients": "Octyldodecyl Stearoyl Stearate, Cocos Nucifera (Coconut) Oil, C10-18 Triglycerides, Copernicia Cerifera (Carnauba) Wax, Hydrogenated Vegetable Oil, Silica, Polyglyceryl-3 Diisostearate, Oryzanol, Glyceryl Undecylenate, Tocopherol...May Contain (+/-) Red 7 Lake (CI 15850), Yellow 5 Lake (CI 19140), Iron Oxides (CI 77491, CI 77492, CI 77499), Titanium Dioxide (CI 77891), Manganese Violet (CI 77742)...The list of ingredients is subject to change, please consult the packaging of the product purchased.",
# 	    "how_to_use": "",
# 	    "num_reviews": 3,
# 	    "overall_rating": 5.0,
# 	    "product_url": "https://www.sephora.com/ca/en/product/cheekbone-horizon-lip-pencil-P509819?skuId=2755726&icid2=products",
# 	    "image_url": "https://www.sephora.com/productimages/sku/s2755726-main-zoom.jpg?imwidth=465",
# 	    "shades": [
# 	        {
# 	            "shade_name": "True Red",
# 	            "shade_descriptor": "",
# 	            "shade_image_url": "https://www.sephora.com/productimages/sku/s2755726-main-zoom.jpg?imwidth=465"
# 	        },
# 	        {
# 	            "shade_name": "Sand",
# 	            "shade_descriptor": "",
# 	            "shade_image_url": "https://www.sephora.com/productimages/sku/s2755718-main-zoom.jpg?imwidth=465"
# 	        },
# 	        {
# 	            "shade_name": "Clay",
# 	            "shade_descriptor": "",
# 	            "shade_image_url": "https://www.sephora.com/productimages/sku/s2755734-main-zoom.jpg?imwidth=465"
# 	        }
# 	    ],
# 	    "reviews": [
# 	        {
# 	            "review_title": "",
# 	            "review_rating": 5,
# 	            "review_shade_purchased": "Sand",
# 	            "review_buyer_description": "Hazel eyes, brown hair, Fair skin tone, Combination skin",
# 	            "review_text": "Great colour, smooth application. Will purchase in other colours"
# 	        }
# 	    ]
# 	},
# 	{
# 	    "product_id": "614",
# 	    "name": "Hand Heroes Exfoliating hand wash and hand cream set",
# 	    "brand": "Grown Alchemist",
# 	    "categories": "Skincare, Value & Gift Sets",
# 	    "price": 49.0,
# 	    "about": "What it is:A limited-edition hand-care kit featuring the newest exfoliating hand wash and bestselling hand cream..Skin Type:Normal, Dry, Combination, and Oily.Skincare Concerns:Dryness, Dullness, and Loss of Firmness and Elasticity.Highlighted Ingredients:- Aloe Vera: Hydrates and refresh..Ingredient Callouts:Free of parabens, formaldehydes, formaldehyde-releasing agents, phthalates, mineral oil, retinyl palmitate, oxybenzone, coal tar, hydroquinone, sulfates SLS & SLES, triclocarban, triclosan, and contains less than one percent synthetic fragrance. It is also vegan, gluten-free, and cruelty-free..What Else You Need to Know:This set includes Grown Alchemistu2019s u200bu200bgentle yet effective hand wash with natural pumice and eco beads that wash away dirt and impurities, leaving hands cleansed, and the beautifully scented, nongreasy hand cream packed with powerful botanicals and nourishing plant oils to moisturize dry hands and cuticles..This Set Contains:- 10 oz/ 300 mL Exfoliating Hand Wash",
# 	    "ingredients": "-Aloe Vera: Hydrates and refresh..-Pumice + Eco Beads: Gently exfoliate to remove dead skin cells for smooth skin...Exfoliating Hand Wash:.Water/Aqua/Eau, Glycerin, Pumice, Pentylene Glycol, Stearyl Stearate, Coco-Glucoside, Sodium Lauroyl Sarcosinate, Caprylyl/Capryl Glucoside, 1,2-Hexanediol, Cellulose Gum, Xanthan Gum, Citrus Aurantium Dulcis (Orange) Peel Extract, Sodium Benzoate, Cocamidopropylamine Oxide, Citric Acid, Sodium Gluconate, Potassium Sorbate, Algin, Glyceryl Oleate, Euphorbia Cerifera (Candelilla) Wax/Euphorbia Cerifera Cera/Cire de candelilla, Jojoba Esters, Aloe Barbadensis Leaf Juice, Citrus Nobilis (Mandarin Orange) Peel Oil, Myrocarpus Fastigiatus Oil, Vanilla Planifolia Fruit Extract, Tocopherol, Rosa Damascena Flower Oil, Hydrogenated Palm Glycerides Citrate, Limonene...Soothing and Softening Vanilla, Orange Peel and Vitamin E Hand Cream:.Water/Aqua/Eau, Vitis Vinifera (Grape) Seed Oil, Dicaprylyl Ether, Glycerin, Camellia Kissi Seed Oil, Heptyl Undecylenate, Cetearyl Alcohol, Glyceryl Stearate Citrate, Polyglyceryl-3 Stearate, Potassium Cetyl Phosphate, Citrus Aurantium Dulcis (Orange) Peel Extract, Palmitic Acid, Stearic Acid, Levulinic Acid, Sodium Benzoate, Sodium Levulinate, Tocopherol, Sodium Gluconate, Xanthan Gum, Potassium Sorbate, Rosa Canina Fruit Oil, Triticum Vulgare (Wheat) Germ Oil, Aloe Barbadensis Leaf Juice, Hippophae Rhamnoides Fruit Oil, Cetyl Alcohol, Glycine Soja (Soybean) Oil, Potassium Phosphate, Citrus Nobilis (Mandarin Orange) Peel Oil, Myrocarpus Fastigiatus Oil, Vanilla Planifolia Fruit Extract, Rosa Damascena Flower Oil, Sodium Riboflavin Phosphate, Potassium Hydroxide, Annatto/CI 75120, Limonene, Linalool.",
# 	    "how_to_use": "wf",
# 	    "num_reviews": 1,
# 	    "overall_rating": 5.0,
# 	    "product_url": "https://www.sephora.com/ca/en/product/grown-alchemist-hand-heroes-exfoliating-hand-wash-hand-cream-set-P514265?skuId=2823953&icid2=products",
# 	    "image_url": "https://www.sephora.com/productimages/sku/s2823953-main-zoom.jpg?imwidth=465",
# 	    "shades": [],
# 	    "reviews": []
# 	},
# 	{
# 	    "product_id": "1413",
# 	    "name": "Nourishing & Repairing Foot Mask",
# 	    "brand": "SEPHORA COLLECTION",
# 	    "categories": "Bath & Body, Body Moisturizers, Hand Cream & Foot Cream",
# 	    "price": 7.0,
# 	    "about": "What it is:A pair of nourishing, repairing foot masks with a festive, limited-edition look..Skin Type:Normal, Dry, Combination, and Oily.What Else You Need to Know:These limited-edition SEPHORA COLLECTION foot masks combine relaxation and holiday vibes. Their festive look is covered in stars, like an icy winter sky. They are formulated with 95 percent ingredients of natural origin and enriched with coconut extract.",
# 	    "ingredients": "Aqua (Water), Glycerin, Butylene Glycol, Macadamia Integrifolia Seed Oil, Cetearyl Alcohol, Pentaerythrityl Tetraethylhexanoate, Cocos Nucifera (Coconut) Fruit Extract, 1,2-Hexanediol, Polyglyceryl-3 Methylglucose Distearate, Glyceryl Stearate, Betaine, Stearic Acid, Parfum (Fragrance), Carbomer, Arginine, O-Cymen-5-Ol, Ethylhexylglycerin, Sodium Hyaluronate, Xanthan Gum, Tocopherol.",
# 	    "how_to_use": "Suggested Usage:.-Cleanse and dry feet. .-Slip on masks as if they were socks. .-Leave on feet for 15 minutes. .-Remove masks and gently massage in any remaining product. .-No need to rinse. ..Precautions: .-Be careful not to slip, avoid walking with the foot masks on, and be sure to massage in any excess product after use.",
# 	    "num_reviews": 10,
# 	    "overall_rating": 5.0,
# 	    "product_url": "https://www.sephora.com/ca/en/product/nourishing-repairing-foot-mask-P513684?skuId=2779825&icid2=products",
# 	    "image_url": "https://www.sephora.com/productimages/sku/s2779825-main-zoom.jpg?imwidth=465",
# 	    "shades": [],
# 	    "reviews": []
# 	},
# 	{
# 	    "product_id": "1043",
# 	    "name": "Flash Color Palette Multi-use Cream Color Palette",
# 	    "brand": "MAKE UP FOR EVER",
# 	    "categories": "Makeup, Makeup Palettes",
# 	    "price": 134.0,
# 	    "about": "What it is:An iconic, must-have palette for pro artists and enthusiasts featuring 12 boldly-pigmented cream shades for the face, lips and body..What Else You Need to Know:Unleash your creativity with this highly-blendable cream formula that effortlessly delivers showstopping color. Each shade can be used individually or mixed to create your dream shade or adjust the undertone of an existing product. This versatile palette is ideal for any level of artistry..This Palette Contains:Artistic Palette:- 12 x 0.21 oz/ 6 g Flash Color in 04 Gold, 02 Coral, 00 Turquoise, 25 Fuchsia, 13 Yellow, 23 Brown, 03 Silver, 10 White, 24 Red, 14 Bright Blue, 8 Leaf Green, 11 Black",
# 	    "ingredients": "",
# 	    "how_to_use": "Suggested Usage:.-Start by using a small amount of product (a little goes a long way with this formula) and apply where desired..-Set with a setting powder such as Super Matte Loose Powder (sold separately)..-Finish with Mist and Fix Setting Spray (sold separately).",
# 	    "num_reviews": 280,
# 	    "overall_rating": 4.4,
# 	    "product_url": "https://www.sephora.com/ca/en/product/flash-color-palette-multi-use-cream-color-palette-P219411?skuId=2112704&icid2=products",
# 	    "image_url": "https://www.sephora.com/productimages/sku/s2112704-main-zoom.jpg?imwidth=465",
# 	    "shades": [
# 	        {
# 	            "shade_name": "Artistic",
# 	            "shade_descriptor": "",
# 	            "shade_image_url": "https://www.sephora.com/productimages/sku/s2112704-main-zoom.jpg?imwidth=465"
# 	        }
# 	    ],
# 	    "reviews": [
# 	        {
# 	            "review_title": "Uhhhu2026",
# 	            "review_rating": 1,
# 	            "review_shade_purchased": "",
# 	            "review_buyer_description": "Brown eyes, Normal skin",
# 	            "review_text": "Is this safe? It looks like they sent me an old one. It has these weird white dotsu2026"
# 	        },
# 	        {
# 	            "review_title": "Love it!",
# 	            "review_rating": 4,
# 	            "review_shade_purchased": "",
# 	            "review_buyer_description": "Blue eyes, blonde hair, fairLight skin tone, Normal skin",
# 	            "review_text": "So much fun to play around with! Consists of primaries to creat any skin tone etc. Love it."
# 	        },
# 	        {
# 	            "review_title": "This is definitely a must have in my makeup kit.",
# 	            "review_rating": 4,
# 	            "review_shade_purchased": "",
# 	            "review_buyer_description": "Green eyes, blonde hair, Light skin tone, Normal skin",
# 	            "review_text": "I am a Makeup Artist and Photographer. My color theory reading pointed me in the direction of the Make Up Forever color palette. Itu2019s the top of

# %%
llm = OpenAI(temperature=0.1, model="gpt-3.5-turbo", max_tokens=512)

nl_query_engine = JSONQueryEngine(
    json_value=json_value,
    json_schema=json_schema,
    llm=llm,
)

# %%
nl_response = nl_query_engine.query(
    "Give me 3 random products that are skincare",
)

display(
    Markdown(f"<h1>Natural language Response</h1><br><b>{nl_response}</b>")
)
# Out:
# ---------------------------------------------------------------------------
# JsonPathParserError                       Traceback (most recent call last)
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/llama_index/core/indices/struct_store/json_query.py:78, in default_output_processor(llm_output, json_value)
#      77 try:
# ---> 78     datum: List[DatumInContext] = parse(expression).find(json_value)
#      79     if datum:
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/jsonpath_ng/ext/parser.py:176, in parse(path, debug)
#     175 def parse(path, debug=False):
# --> 176     return ExtentedJsonPathParser(debug=debug).parse(path)
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/jsonpath_ng/parser.py:58, in JsonPathParser.parse(self, string, lexer)
#      57 lexer = lexer or self.lexer_class()
# ---> 58 return self.parse_token_stream(lexer.tokenize(string))
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/jsonpath_ng/parser.py:61, in JsonPathParser.parse_token_stream(self, token_iterator)
#      60 def parse_token_stream(self, token_iterator):
# ---> 61     return self.parser.parse(lexer = IteratorToTokenStream(token_iterator))
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/ply/yacc.py:333, in LRParser.parse(self, input, lexer, debug, tracking, tokenfunc)
#     332 else:
# --> 333     return self.parseopt_notrack(input, lexer, debug, tracking, tokenfunc)
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/ply/yacc.py:1201, in LRParser.parseopt_notrack(self, input, lexer, debug, tracking, tokenfunc)
#    1200 self.state = state
# -> 1201 tok = call_errorfunc(self.errorfunc, errtoken, self)
#    1202 if self.errorok:
#    1203     # User must have done some kind of panic
#    1204     # mode recovery on their own.  The
#    1205     # returned token is the next lookahead
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/ply/yacc.py:192, in call_errorfunc(errorfunc, token, parser)
#     191 _restart = parser.restart
# --> 192 r = errorfunc(token)
#     193 try:
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/jsonpath_ng/parser.py:78, in JsonPathParser.p_error(self, t)
#      77     raise JsonPathParserError('Parse error near the end of string!')
# ---> 78 raise JsonPathParserError('Parse error at %s:%s near token %s (%s)'
#      79                           % (t.lineno, t.col, t.value, t.type))
#
# JsonPathParserError: Parse error at 1:34 near token ( (()
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 3
#       1 os.environ["OPENAI_API_KEY"] = "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"
# ----> 3 nl_response = nl_query_engine.query(
#       4     "Give me 3 random products that are skincare",
#       5 )
#       7 display(
#       8     Markdown(f"<h1>Natural language Response</h1><br><b>{nl_response}</b>")
#       9 )
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/llama_index/core/base/base_query_engine.py:52, in BaseQueryEngine.query(self, str_or_query_bundle)
#      50     if isinstance(str_or_query_bundle, str):
#      51         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 52     query_result = self._query(str_or_query_bundle)
#      53 dispatcher.event(
#      54     QueryEndEvent(query=str_or_query_bundle, response=query_result)
#      55 )
#      56 return query_result
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/llama_index/core/indices/struct_store/json_query.py:171, in JSONQueryEngine._query(self, query_bundle)
#     166 if self._verbose:
#     167     print_text(
#     168         f"> JSONPath Instructions:\n" f"```\n{json_path_response_str}\n```\n"
#     169     )
# --> 171 json_path_output = self._output_processor(
#     172     json_path_response_str,
#     173     self._json_value,
#     174     **self._output_kwargs,
#     175 )
#     177 # removes JSONPath: prefix from returned JSON path prompt call
#     178 if self._json_path_prompt == DEFAULT_JSON_PATH_PROMPT:
#
# File ~/Documents/UofT/capstone/Personal-Shopping-Site/venv/lib/python3.9/site-packages/llama_index/core/indices/struct_store/json_query.py:85, in default_output_processor(llm_output, json_value)
#      83             results[key] = ", ".join(str(i.value) for i in datum)
#      84     except Exception as exc:
# ---> 85         raise ValueError(f"Invalid JSON Path: {expression}") from exc
#      87 return results
#
# ValueError: Invalid JSON Path: $.products[?(@.categories.includes('Skincare'))][:3]
